# %% [markdown]
# Imports

# %%
import preamble

import random
from robot import Robot
from console_command_thread import ConsoleCommandThread
from phrase_trial_data import PhraseTrialData

# %% [markdown]
# Bake corpus (which is a subset of the universe of phrases)

# %%
universe = {
    'prefix': [
        'I need you to',
        'I am telling you to',
        'I think you should',
        'It would be nice if you',
        'You should',
        'I think you should',
        'Can you',
        'Could you',
        'Please',
        'You must',
    ],
    'adverb': [
        'slightly',
        'greatly',
        'smoothly',
        'sharply',
        'slowly',
        'quickly',
        'lightly',
        'significantly',
        'softly',
        'harshly',
        'gradually',
        'immediately',
    ],
    'action': {
        'without target': [
            'move',
            'shift',
            'adjust',
            'proceed',
            'ease',
            'head',
            'scoot',
            'advance',
            'go',
        ],
        'with target': [
            'bring it',
            'take it',
            'move it',
            'shift it',
            'adjust it',
            'proceed it',
            'ease it',
            'scoot it',
            'advance it',
            'move yourself',
            'shift yourself',
            'adjust yourself',
            'proceed yourself',
            'ease yourself',
            'head yourself',
            'scoot yourself',
            'advance yourself',
        ],
    },
    'direction': [
        'left',
        'right',
        'up',
        'down',
        'forward',
        'backward',
    ],
}

def choose_random_part(universe, phrase_part_type):
    o = universe[phrase_part_type]
    if isinstance(o, dict):
        return choose_random_part(o, random.choice(list(o.keys())))
    elif isinstance(o, list):
        return random.choice(o)

phrase_categories = [
    ('direction',),
    ('action', 'direction'),
    ('adverb', 'action', 'direction'),
    ('prefix', 'action', 'direction'),
    ('prefix', 'adverb', 'action', 'direction'),
]

NUMBER_OF_USERS = 12
NUMBER_OF_EACH_CATEGORY = 8

corpus = [universe['direction']]

for phrase_category in phrase_categories[1:]:
    phrases_of_category = []
    for _ in range(NUMBER_OF_EACH_CATEGORY * NUMBER_OF_USERS):
        phrase_parts = []
        for phrase_part_type in phrase_category:
            phrase_parts.append(choose_random_part(universe, phrase_part_type))
        print(phrase_parts)
        phrases_of_category.append(' '.join(phrase_parts))
    corpus.append(phrases_of_category)
# Out:
# ['adjust', 'left']
# ['go', 'down']
# ['move yourself', 'backward']
# ['head yourself', 'right']
# ['proceed', 'backward']
# ['scoot', 'backward']
# ['head yourself', 'right']
# ['scoot yourself', 'left']
# ['scoot', 'down']
# ['shift', 'down']
# ['scoot it', 'up']
# ['move', 'left']
# ['bring it', 'forward']
# ['proceed it', 'up']
# ['shift', 'left']
# ['scoot', 'backward']
# ['head', 'right']
# ['advance', 'right']
# ['adjust it', 'down']
# ['scoot it', 'left']
# ['bring it', 'backward']
# ['shift it', 'up']
# ['head', 'right']
# ['scoot yourself', 'left']
# ['proceed it', 'down']
# ['proceed', 'down']
# ['head yourself', 'backward']
# ['scoot yourself', 'right']
# ['ease', 'up']
# ['proceed yourself', 'up']
# ['go', 'right']
# ['go', 'forward']
# ['move it', 'right']
# ['advance yourself', 'right']
# ['adjust yourself', 'backward']
# ['go', 'right']
# ['advance it', 'right']
# ['ease', 'up']
# ['move', 'up']
# ['go', 'right']
# ['take it', 'right']
# ['move yourself', 'backward']
# ['head yourself', 'forward']
# ['head yourself', 'down']
# ['adjust it', 'up']
# ['adjust yourself', 'down']
# ['ease it', 'right']
# ['proceed yourself', 'backward']
# ['ease it', 'right']
# ['proceed it', 'forward']
# ['advance', 'backward']
# ['adjust', 'left']
# ['take it', 'right']
# ['adjust', 'right']
# ['go', 'forward']
# ['ease', 'down']
# ['take it', 'down']
# ['move yourself', 'up']
# ['shift', 'down']
# ['shift it', 'right']
# ['move', 'left']
# ['ease yourself', 'up']
# ['advance yourself', 'right']
# ['go', 'up']
# ['advance it', 'up']
# ['ease yourself', 'right']
# ['advance yourself', 'forward']
# ['ease it', 'right']
# ['move it', 'forward']
# ['shift yourself', 'backward']
# ['scoot it', 'down']
# ['go', 'up']
# ['adjust yourself', 'right']
# ['head', 'backward']
# ['adjust yourself', 'left']
# ['move yourself', 'up']
# ['shift', 'backward']
# ['proceed yourself', 'up']
# ['scoot', 'up']
# ['bring it', 'forward']
# ['ease yourself', 'right']
# ['go', 'forward']
# ['proceed', 'down']
# ['ease', 'right']
# ['scoot', 'backward']
# ['proceed', 'forward']
# ['scoot it', 'backward']
# ['adjust', 'right']
# ['proceed it', 'down']
# ['proceed yourself', 'left']
# ['adjust', 'left']
# ['go', 'down']
# ['ease it', 'right']
# ['ease it', 'left']
# ['move', 'left']
# ['ease yourself', 'right']
# ['slightly', 'proceed', 'right']
# ['softly', 'shift it', 'down']
# ['sharply', 'head', 'right']
# ['sharply', 'adjust', 'forward']
# ['quickly', 'head yourself', 'backward']
# ['lightly', 'head', 'left']
# ['quickly', 'move', 'forward']
# ['smoothly', 'ease', 'up']
# ['immediately', 'advance', 'backward']
# ['significantly', 'shift yourself', 'backward']
# ['greatly', 'ease yourself', 'left']
# ['lightly', 'ease', 'backward']
# ['greatly', 'go', 'forward']
# ['greatly', 'move', 'forward']
# ['smoothly', 'adjust it', 'forward']
# ['gradually', 'scoot it', 'up']
# ['slowly', 'head', 'down']
# ['sharply', 'ease yourself', 'right']
# ['immediately', 'head yourself', 'forward']
# ['immediately', 'move', 'forward']
# ['smoothly', 'move it', 'forward']
# ['harshly', 'ease yourself', 'backward']
# ['greatly', 'shift it', 'up']
# ['slowly', 'take it', 'left']
# ['quickly', 'go', 'right']
# ['harshly', 'adjust yourself', 'down']
# ['harshly', 'advance yourself', 'left']
# ['significantly', 'move it', 'right']
# ['immediately', 'advance', 'right']
# ['greatly', 'advance yourself', 'left']
# ['slightly', 'bring it', 'forward']
# ['immediately', 'scoot yourself', 'backward']
# ['lightly', 'go', 'left']
# ['slightly', 'advance yourself', 'backward']
# ['sharply', 'scoot yourself', 'up']
# ['sharply', 'ease', 'right']
# ['softly', 'ease yourself', 'left']
# ['quickly', 'adjust', 'backward']
# ['gradually', 'move', 'left']
# ['significantly', 'adjust', 'down']
# ['gradually', 'bring it', 'backward']
# ['sharply', 'proceed yourself', 'up']
# ['immediately', 'move yourself', 'down']
# ['lightly', 'shift yourself', 'down']
# ['harshly', 'head', 'right']
# ['slowly', 'scoot', 'down']
# ['greatly', 'head', 'right']
# ['gradually', 'scoot', 'up']
# ['harshly', 'advance yourself', 'right']
# ['slowly', 'proceed yourself', 'forward']
# ['gradually', 'advance yourself', 'down']
# ['immediately', 'bring it', 'backward']
# ['sharply', 'proceed it', 'backward']
# ['significantly', 'shift it', 'left']
# ['smoothly', 'head yourself', 'right']
# ['quickly', 'move it', 'forward']
# ['quickly', 'proceed', 'right']
# ['softly', 'proceed', 'forward']
# ['smoothly', 'shift it', 'up']
# ['lightly', 'scoot yourself', 'right']
# ['harshly', 'adjust it', 'left']
# ['slightly', 'move it', 'up']
# ['smoothly', 'advance', 'left']
# ['softly', 'ease yourself', 'down']
# ['quickly', 'proceed', 'left']
# ['greatly', 'adjust yourself', 'left']
# ['sharply', 'head', 'left']
# ['harshly', 'adjust', 'down']
# ['smoothly', 'adjust it', 'down']
# ['greatly', 'bring it', 'left']
# ['gradually', 'move it', 'up']
# ['immediately', 'ease it', 'backward']
# ['harshly', 'proceed yourself', 'backward']
# ['significantly', 'adjust yourself', 'down']
# ['sharply', 'adjust', 'up']
# ['significantly', 'scoot it', 'left']
# ['quickly', 'move it', 'down']
# ['harshly', 'adjust', 'forward']
# ['slightly', 'ease', 'down']
# ['smoothly', 'advance yourself', 'backward']
# ['significantly', 'ease it', 'left']
# ['quickly', 'proceed it', 'left']
# ['lightly', 'head', 'forward']
# ['greatly', 'adjust', 'forward']
# ['slightly', 'adjust it', 'up']
# ['harshly', 'advance it', 'up']
# ['softly', 'move', 'down']
# ['greatly', 'move', 'up']
# ['softly', 'adjust', 'right']
# ['slightly', 'ease yourself', 'up']
# ['smoothly', 'move it', 'left']
# ['sharply', 'move', 'left']
# ['smoothly', 'proceed yourself', 'up']
# ['gradually', 'ease it', 'backward']
# ['gradually', 'head yourself', 'forward']
# ['quickly', 'scoot', 'right']
# ['I need you to', 'ease it', 'backward']
# ['It would be nice if you', 'ease it', 'forward']
# ['Could you', 'ease', 'right']
# ['Could you', 'head yourself', 'up']
# ['I think you should', 'proceed', 'up']
# ['You must', 'ease it', 'left']
# ['You must', 'bring it', 'down']
# ['I think you should', 'move yourself', 'down']
# ['Please', 'bring it', 'down']
# ['Can you', 'proceed', 'backward']
# ['It would be nice if you', 'scoot it', 'down']
# ['You should', 'move', 'left']
# ['Could you', 'ease yourself', 'right']
# ['It would be nice if you', 'proceed yourself', 'backward']
# ['I need you to', 'ease', 'forward']
# ['It would be nice if you', 'ease yourself', 'down']
# ['I think you should', 'shift it', 'left']
# ['You should', 'advance', 'forward']
# ['I think you should', 'proceed', 'forward']
# ['You must', 'head', 'backward']
# ['It would be nice if you', 'proceed', 'backward']
# ['Can you', 'go', 'left']
# ['You should', 'advance', 'down']
# ['It would be nice if you', 'ease', 'backward']
# ['You must', 'go', 'backward']
# ['I am telling you to', 'ease', 'right']
# ['I think you should', 'shift', 'backward']
# ['Please', 'advance', 'backward']
# ['It would be nice if you', 'shift', 'right']
# ['You should', 'bring it', 'left']
# ['You should', 'go', 'right']
# ['I need you to', 'shift yourself', 'forward']
# ['I think you should', 'ease', 'left']
# ['It would be nice if you', 'proceed it', 'down']
# ['I need you to', 'go', 'backward']
# ['Can you', 'move yourself', 'backward']
# ['Could you', 'proceed yourself', 'right']
# ['Can you', 'head', 'forward']
# ['Can you', 'move it', 'backward']
# ['Please', 'scoot it', 'forward']
# ['I am telling you to', 'proceed it', 'down']
# ['You should', 'move', 'backward']
# ['Could you', 'head yourself', 'down']
# ['Please', 'proceed', 'right']
# ['It would be nice if you', 'adjust', 'left']
# ['You must', 'scoot yourself', 'backward']
# ['You should', 'shift', 'backward']
# ['Please', 'advance', 'up']
# ['Please', 'advance it', 'left']
# ['Please', 'move', 'down']
# ['I think you should', 'shift it', 'forward']
# ['I think you should', 'go', 'backward']
# ['I think you should', 'advance', 'backward']
# ['It would be nice if you', 'adjust yourself', 'right']
# ['I need you to', 'ease', 'right']
# ['You should', 'proceed it', 'backward']
# ['You should', 'advance it', 'up']
# ['Please', 'move it', 'left']
# ['You should', 'ease yourself', 'backward']
# ['You must', 'proceed', 'left']
# ['I am telling you to', 'head', 'up']
# ['I am telling you to', 'proceed yourself', 'up']
# ['You should', 'adjust yourself', 'backward']
# ['You should', 'bring it', 'down']
# ['I am telling you to', 'move', 'right']
# ['Can you', 'proceed', 'right']
# ['Could you', 'move', 'forward']
# ['Could you', 'ease yourself', 'right']
# ['Please', 'ease yourself', 'up']
# ['I am telling you to', 'bring it', 'backward']
# ['I think you should', 'go', 'left']
# ['I think you should', 'proceed', 'left']
# ['Please', 'ease', 'forward']
# ['I think you should', 'scoot yourself', 'backward']
# ['Could you', 'head', 'backward']
# ['Can you', 'head yourself', 'right']
# ['You must', 'ease yourself', 'forward']
# ['I think you should', 'proceed yourself', 'left']
# ['I need you to', 'bring it', 'right']
# ['Can you', 'take it', 'right']
# ['I think you should', 'scoot', 'left']
# ['Can you', 'ease', 'up']
# ['Could you', 'scoot', 'right']
# ['It would be nice if you', 'adjust', 'up']
# ['I think you should', 'proceed', 'right']
# ['Could you', 'shift it', 'forward']
# ['Please', 'head', 'forward']
# ['I think you should', 'bring it', 'left']
# ['You must', 'adjust', 'up']
# ['You must', 'adjust', 'up']
# ['Please', 'advance yourself', 'down']
# ['I think you should', 'adjust yourself', 'forward']
# ['You should', 'ease yourself', 'down']
# ['It would be nice if you', 'shift yourself', 'right']
# ['Can you', 'adjust', 'left']
# ['It would be nice if you', 'head', 'down']
# ['Please', 'softly', 'proceed yourself', 'backward']
# ['I need you to', 'slowly', 'move it', 'down']
# ['I think you should', 'smoothly', 'shift', 'backward']
# ['It would be nice if you', 'slightly', 'proceed', 'down']
# ['Can you', 'significantly', 'scoot', 'up']
# ['You must', 'softly', 'head yourself', 'backward']
# ['You should', 'gradually', 'proceed', 'backward']
# ['I am telling you to', 'sharply', 'shift it', 'up']
# ['Could you', 'slightly', 'proceed', 'left']
# ['I think you should', 'softly', 'advance yourself', 'up']
# ['I am telling you to', 'smoothly', 'take it', 'up']
# ['Can you', 'quickly', 'go', 'up']
# ['Can you', 'slightly', 'adjust', 'up']
# ['You should', 'slightly', 'head yourself', 'down']
# ['Can you', 'sharply', 'move yourself', 'right']
# ['I think you should', 'greatly', 'scoot', 'backward']
# ['Please', 'harshly', 'ease it', 'up']
# ['You must', 'slightly', 'adjust', 'forward']
# ['You should', 'slightly', 'ease', 'backward']
# ['Please', 'gradually', 'adjust', 'right']
# ['I need you to', 'greatly', 'head yourself', 'up']
# ['You should', 'immediately', 'scoot yourself', 'right']
# ['Could you', 'significantly', 'move it', 'backward']
# ['I think you should', 'significantly', 'shift it', 'right']
# ['You should', 'harshly', 'shift yourself', 'down']
# ['I need you to', 'slowly', 'advance', 'down']
# ['Please', 'slightly', 'ease yourself', 'left']
# ['You must', 'sharply', 'move', 'up']
# ['I need you to', 'lightly', 'go', 'forward']
# ['I need you to', 'smoothly', 'ease it', 'right']
# ['I need you to', 'slowly', 'ease', 'backward']
# ['You must', 'significantly', 'proceed', 'right']
# ['Can you', 'harshly', 'take it', 'left']
# ['I think you should', 'sharply', 'scoot', 'forward']
# ['Could you', 'gradually', 'adjust yourself', 'left']
# ['I think you should', 'softly', 'proceed', 'up']
# ['I think you should', 'quickly', 'adjust', 'forward']
# ['You must', 'greatly', 'scoot it', 'forward']
# ['I think you should', 'smoothly', 'ease', 'down']
# ['I need you to', 'sharply', 'shift yourself', 'backward']
# ['I am telling you to', 'sharply', 'ease', 'down']
# ['You must', 'softly', 'proceed', 'backward']
# ['I think you should', 'gradually', 'shift it', 'down']
# ['It would be nice if you', 'greatly', 'scoot it', 'backward']
# ['I think you should', 'greatly', 'shift', 'forward']
# ['It would be nice if you', 'significantly', 'take it', 'up']
# ['You should', 'smoothly', 'shift yourself', 'forward']
# ['Please', 'gradually', 'proceed', 'forward']
# ['Could you', 'lightly', 'proceed yourself', 'backward']
# ['You should', 'gradually', 'go', 'up']
# ['I think you should', 'slightly', 'proceed', 'forward']
# ['You should', 'smoothly', 'shift it', 'backward']
# ['You must', 'slowly', 'advance', 'up']
# ['You should', 'quickly', 'shift', 'forward']
# ['Please', 'significantly', 'scoot it', 'right']
# ['I am telling you to', 'smoothly', 'adjust it', 'down']
# ['You should', 'slightly', 'shift', 'backward']
# ['You must', 'gradually', 'proceed yourself', 'backward']
# ['I need you to', 'sharply', 'adjust', 'left']
# ['Can you', 'gradually', 'head yourself', 'up']
# ['Can you', 'significantly', 'move', 'down']
# ['Please', 'harshly', 'advance it', 'left']
# ['It would be nice if you', 'gradually', 'go', 'left']
# ['Please', 'harshly', 'shift it', 'down']
# ['I need you to', 'slightly', 'shift', 'down']
# ['It would be nice if you', 'greatly', 'shift yourself', 'up']
# ['Can you', 'slowly', 'ease it', 'backward']
# ['I need you to', 'smoothly', 'head yourself', 'forward']
# ['I think you should', 'quickly', 'shift', 'up']
# ['Please', 'harshly', 'scoot', 'right']
# ['You must', 'harshly', 'adjust', 'forward']
# ['I think you should', 'quickly', 'go', 'down']
# ['I need you to', 'slightly', 'scoot', 'up']
# ['I think you should', 'gradually', 'head', 'backward']
# ['Could you', 'immediately', 'proceed', 'right']
# ['You should', 'lightly', 'head', 'down']
# ['Please', 'softly', 'scoot', 'backward']
# ['Please', 'immediately', 'adjust', 'down']
# ['It would be nice if you', 'significantly', 'scoot', 'up']
# ['I need you to', 'slowly', 'adjust it', 'forward']
# ['Could you', 'quickly', 'proceed', 'down']
# ['I am telling you to', 'significantly', 'move yourself', 'up']
# ['It would be nice if you', 'gradually', 'scoot yourself', 'backward']
# ['Could you', 'slightly', 'bring it', 'forward']
# ['I am telling you to', 'harshly', 'adjust it', 'forward']
# ['I need you to', 'softly', 'go', 'backward']
# ['I need you to', 'softly', 'move it', 'right']
# ['Can you', 'smoothly', 'proceed it', 'down']
# ['You must', 'sharply', 'scoot yourself', 'backward']
# ['It would be nice if you', 'lightly', 'scoot yourself', 'forward']
# ['I am telling you to', 'slowly', 'head', 'down']
# ['I think you should', 'sharply', 'head yourself', 'down']
# ['I am telling you to', 'harshly', 'advance', 'right']
# ['You should', 'sharply', 'move yourself', 'forward']
# ['I think you should', 'slightly', 'shift it', 'forward']
# ['I am telling you to', 'slightly', 'advance it', 'right']

# %% [markdown]
# Experiment

# %%
with Robot(
    '169.254.9.43',
    translational_force_deadband=6.0,
    rotational_force_deadband=0.5
) as r, ConsoleCommandThread() as c:
